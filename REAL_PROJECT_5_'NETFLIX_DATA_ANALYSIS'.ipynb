# %% [markdown]
# <a href="https://colab.research.google.com/github/ravirude/Project_Portfolio/blob/main/REAL_PROJECT_5_'NETFLIX_DATA_ANALYSIS'.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("8. Netflix Dataset.csv")

# %%
df.head()
# Out:
#   Show_Id  ...                                        Description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 11 columns]

# %%
df.tail()
# Out:
#      Show_Id  ...                                        Description
# 7784   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7785   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7786   s7785  ...  In this documentary, South African rapper Nast...
# 7787   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7788   s7787  ...  This documentary delves into the mystique behi...
#
# [5 rows x 11 columns]

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Q1. Is any duplicate record in this dataset.? if yes then remove the duplicate records.

# %%
df.head()   ## First we check top five records
# Out:
#   Show_Id  ...                                        Description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 11 columns]

# %%
df.shape  ## we check shape of data.
# Out:
# (7789, 11)

# %%
df[df.duplicated()]      ## To check row wise and detect the duplicate row.
# Out:
#      Show_Id  ...                                        Description
# 6300    s684  ...  When two would-be robbers accidentally kill a ...
# 6622   s6621  ...  A disillusioned security guard transforms into...
#
# [2 rows x 11 columns]

# %%
df.drop_duplicates(inplace = True)    ## Remove the duplicates rows permanetely.

# %%
df[df.duplicated()]   ## Now all duplicate rows are permanently remove.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# # Q2. Is any null value present in coloumn.? show with heat map.

# %%
df.head()
# Out:
#   Show_Id  ...                                        Description
# 0      s1  ...  In a future where the elite inhabit an island ...
# 1      s2  ...  After a devastating earthquake hits Mexico Cit...
# 2      s3  ...  When an army recruit is found dead, his fellow...
# 3      s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4      s5  ...  A brilliant group of students become card-coun...
#
# [5 rows x 11 columns]

# %%
df.isnull()   ## To show where is null value is present.
# Out:
#       Show_Id  Category  Title  Director  ...  Rating  Duration   Type  Description
# 0       False     False  False      True  ...   False     False  False        False
# 1       False     False  False     False  ...   False     False  False        False
# 2       False     False  False     False  ...   False     False  False        False
# 3       False     False  False     False  ...   False     False  False        False
# 4       False     False  False     False  ...   False     False  False        False
# ...       ...       ...    ...       ...  ...     ...       ...    ...          ...
# 7784    False     False  False     False  ...   False     False  False        False
# 7785    False     False  False     False  ...   False     False  False        False
# 7786    False     False  False      True  ...   False     False  False        False
# 7787    False     False  False      True  ...   False     False  False        False
# ...

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# # seaborn library (heat map)

# %%
import seaborn as sns         ## To import seaborn library.

# %%
sns.heatmap(df.isnull())      ## To use heatmap to show null values/missing values counts.

# %% [markdown]
# Q3. 'For House of Card' what is the show ID and who is Director of this show.?

# %%
df[df['Title'].isin(['House of Cards'])]      ## To show all records of a particular item in any column
# Out:
#      Show_Id  ...                                        Description
# 2832   s2833  ...  A ruthless politician will stop at nothing to ...
#
# [1 rows x 11 columns]

# %%
df[df['Title'].str.contains('House of Cards')]      ## To show all records of a particular string in any column
# Out:
#      Show_Id  ...                                        Description
# 2832   s2833  ...  A ruthless politician will stop at nothing to ...
#
# [1 rows x 11 columns]

# %% [markdown]
# # Q4. In which year highest number of the TV Shows and Movies were released.? show with bar graph.

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'])

# %%
df.head()
# Out:
#   Show_Id  ...     Date_N
# 0      s1  ... 2020-08-14
# 1      s2  ... 2016-12-23
# 2      s3  ... 2018-12-20
# 3      s4  ... 2017-11-16
# 4      s5  ... 2020-01-01
#
# [5 rows x 12 columns]

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
df['Date_N'].dt.year.value_counts()     ## So ans is 2019 where Highest no of TV Shows and Movies Release(2153 total).
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# Show ans in Bar Graph.

# %%
df['Date_N'].dt.year.value_counts().plot(kind = 'bar')

# %% [markdown]
# # Q5. How many Movies and TV shows are in Dataset.? Show in bar graph.

# %%
df.head(2)
# Out:
#   Show_Id  ...     Date_N
# 0      s1  ... 2020-08-14
# 1      s2  ... 2016-12-23
#
# [2 rows x 12 columns]

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
df.groupby('Category').	Category.count().plot(kind = 'bar')

# %% [markdown]
# # Q6. Show the all Movies were Release in Year 2000.

# %%
df.head(2)
# Out:
#   Show_Id  ...     Date_N
# 0      s1  ... 2020-08-14
# 1      s2  ... 2016-12-23
#
# [2 rows x 12 columns]

# %%
df['Year'] = df['Date_N'].dt.year

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2000)]         ## So ans is there were No any Movies Release in Year 2000.
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
df[(df['Category'] == 'Movie') & (df['Year'] == 2019)]          ## So ans is there were 1497 Movies Release in Year 2019.
# Out:
#      Show_Id Category  ...     Date_N    Year
# 7         s8    Movie  ... 2019-11-01  2019.0
# 8         s9    Movie  ... 2019-04-01  2019.0
# 13       s14    Movie  ... 2019-03-01  2019.0
# 15       s16    Movie  ... 2019-09-01  2019.0
# 18       s19    Movie  ... 2019-03-29  2019.0
# ...      ...      ...  ...        ...     ...
# 7771   s7770    Movie  ... 2019-12-15  2019.0
# 7775   s7774    Movie  ... 2019-11-01  2019.0
# 7776   s7775    Movie  ... 2019-11-20  2019.0
# 7780   s7779    Movie  ... 2019-11-01  2019.0
# 7785   s7784    Movie  ... 2019-03-02  2019.0
#
# [1497 rows x 13 columns]

# %% [markdown]
# # Q7. Show only the Titles of all TV shows that were Release in India only.

# %%
df[(df['Category'] == 'TV Show') & (df['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# # Q8. Show Top 10 Director, Who gave the highest number of TV Shows and Movies on Netflix.

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Quentin Tarantino          8
# Name: Director, dtype: int64

# %% [markdown]
# # Q9. Shows all the records where 'Category is Movies and Type is Commedian' or 'Country is United Kindom'.

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df[(df['Category']=='Movie') & (df['Type'] =='Comedies')]
# Out:
#      Show_Id Category  ...     Date_N    Year
# 33       s34    Movie  ... 2017-09-08  2017.0
# 72       s73    Movie  ... 2021-01-01  2021.0
# 84       s85    Movie  ... 2019-04-16  2019.0
# 148     s149    Movie  ... 2020-02-14  2020.0
# 174     s175    Movie  ... 2018-01-26  2018.0
# ...      ...      ...  ...        ...     ...
# 7341   s7340    Movie  ... 2019-11-05  2019.0
# 7590   s7589    Movie  ... 2018-01-22  2018.0
# 7623   s7622    Movie  ... 2017-05-13  2017.0
# 7634   s7633    Movie  ... 2019-05-10  2019.0
# 7664   s7663    Movie  ... 2020-08-07  2020.0
#
# [97 rows x 13 columns]

# %% [markdown]
# Country is United Kindom

# %%
df[(df['Category']== 'Movie') & (df['Type']=='Comedies') | (df['Country']=='United Kingdom')]   ## Using here or Operater.
# Out:
#      Show_Id Category  ...     Date_N    Year
# 19       s20    Movie  ... 2018-05-16  2018.0
# 33       s34    Movie  ... 2017-09-08  2017.0
# 58       s59  TV Show  ... 2019-11-01  2019.0
# 72       s73    Movie  ... 2021-01-01  2021.0
# 82       s83    Movie  ... 2018-12-20  2018.0
# ...      ...      ...  ...        ...     ...
# 7670   s7669  TV Show  ... 2017-08-01  2017.0
# 7671   s7670  TV Show  ... 2019-02-01  2019.0
# 7688   s7687    Movie  ... 2020-03-18  2020.0
# 7725   s7724    Movie  ... 2017-12-31  2017.0
# 7740   s7739  TV Show  ... 2020-09-03  2020.0
#
# [485 rows x 13 columns]

# %% [markdown]
# # Q10. In how many Movies and TV Shows where Tom Crulse cast.

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df[(df['Cast'] == 'Tom Cruise')]    ## So ans is zero Movies of Tom Crulse Because this code not working due to multiple cast here with Tom Cruise. So we use 'string function'
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# Second Method 'str.contains'

# %%
df[df['Cast'].str.contains('Tom Crulse')]         ## Cannot mask with non-boolean array containing NA / NaN values. So it is clear cut say str function not work on Null values.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-15e89dd1054d> in <module>()
# ----> 1 df[df['Cast'].str.contains('Tom Crulse')]         ## Cannot mask with non-boolean array containing NA / NaN values. So it is clear cut say str function not work on Null values.
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
# -> 2896         if com.is_bool_indexer(key):
#    2897             return self._getitem_bool_array(key)
#    2898
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
# ...

# %% [markdown]
# Creating New Data frame.

# %%
df_new = df.dropna()      ## It drop all null value/Missing value from data.

# %%
df_new.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 1      s2    Movie  ... 2016-12-23  2016.0
# 2      s3    Movie  ... 2018-12-20  2018.0
#
# [2 rows x 13 columns]

# %%
df_new[df_new['Cast'].str.contains('Tom Cruise')]   ## Now as above we drop null value so this code where we use 'string' is run.
# Out:
#      Show_Id Category  ...     Date_N    Year
# 3860   s3861    Movie  ... 2020-01-01  2020.0
# 5071   s5071    Movie  ... 2019-07-01  2019.0
#
# [2 rows x 13 columns]

# %% [markdown]
# # Q11. What are the different ratings which is defined by Netflix.

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df.Rating.nunique()    ## we use here 'nunique' function for find no of unique rating the ans is '14'
# Out:
# 14

# %%
df.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# # Q12. How many movies geting 'TV-14' Rating in Canada

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14')]
# Out:
#      Show_Id Category  ...     Date_N    Year
# 8         s9    Movie  ... 2019-04-01  2019.0
# 15       s16    Movie  ... 2019-09-01  2019.0
# 18       s19    Movie  ... 2019-03-29  2019.0
# 20       s21    Movie  ... 2018-09-01  2018.0
# 21       s22    Movie  ... 2018-09-15  2018.0
# ...      ...      ...  ...        ...     ...
# 7765   s7764    Movie  ... 2018-02-15  2018.0
# 7766   s7765    Movie  ... 2019-05-21  2019.0
# 7770   s7769    Movie  ... 2018-10-01  2018.0
# 7771   s7770    Movie  ... 2019-12-15  2019.0
# 7785   s7784    Movie  ... 2019-03-02  2019.0
#
# [1272 rows x 13 columns]

# %%
df[(df['Category'] == 'Movie') & (df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')]
# Out:
#      Show_Id Category  ...     Date_N    Year
# 30       s31    Movie  ... 2020-02-05  2020.0
# 34       s35    Movie  ... 2019-04-10  2019.0
# 608     s609    Movie  ... 2018-12-27  2018.0
# 1506   s1507    Movie  ... 2018-07-01  2018.0
# 3713   s3714    Movie  ... 2017-11-12  2017.0
# 3956   s3957    Movie  ... 2019-10-14  2019.0
# 5336   s5336    Movie  ... 2017-08-22  2017.0
# 5393   s5393    Movie  ... 2017-12-01  2017.0
# 6062   s6062    Movie  ... 2019-07-01  2019.0
# 7025   s7024    Movie  ... 2019-06-18  2019.0
# 7041   s7040    Movie  ... 2020-03-27  2020.0
#
# [11 rows x 13 columns]

# %% [markdown]
# # Q13. How many TV shows got 'R' Rating after year 2018.

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R')]
# Out:
#      Show_Id Category  ...     Date_N    Year
# 4497   s4498  TV Show  ... 2016-12-10  2016.0
# 6437   s6436  TV Show  ... 2019-04-25  2019.0
#
# [2 rows x 13 columns]

# %%
df[(df['Category'] == 'TV Show') & (df['Rating'] == 'R') & (df['Year'] > 2018)]
# Out:
#      Show_Id Category  ...     Date_N    Year
# 6437   s6436  TV Show  ... 2019-04-25  2019.0
#
# [1 rows x 13 columns]

# %% [markdown]
# # Q14. What is maximum duration of a Movie/TV Show on Netflix.

# %%
df.head(2)
# Out:
#   Show_Id Category  ...     Date_N    Year
# 0      s1  TV Show  ... 2020-08-14  2020.0
# 1      s2    Movie  ... 2016-12-23  2016.0
#
# [2 rows x 13 columns]

# %%
df['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
df.Duration.dtypes
# Out:
# dtype('O')

# %%
df[['Minutes', 'Unit']] = df['Duration'].str.split(' ', expand = True)

# %%
df.head(2)
# Out:
#   Show_Id Category  Title  ...    Year Minutes     Unit
# 0      s1  TV Show     3%  ...  2020.0       4  Seasons
# 1      s2    Movie  07:19  ...  2016.0      93      min
#
# [2 rows x 15 columns]

# %% [markdown]
# Now Find maximum duration.

# %%
df.Minutes.max()
# Out:
# '99'

# %%
df.Minutes.min()
# Out:
# '1'

# %%
df.Minutes.mean()
# Out:
# inf

# %% [markdown]
# # Q15. Which Indivdual Country has Highest No of TV Show.

# %%
df.head(2)
# Out:
#   Show_Id Category  Title  ...    Year Minutes     Unit
# 0      s1  TV Show     3%  ...  2020.0       4  Seasons
# 1      s2    Movie  07:19  ...  2016.0      93      min
#
# [2 rows x 15 columns]

# %%
df_TVshow = df[df['Category'] == 'TV Show']   ## Here we create only TV Show .

# %%
df_TVshow.head(2)
# Out:
#   Show_Id Category Title     Director  ...     Date_N    Year Minutes     Unit
# 0      s1  TV Show    3%          NaN  ... 2020-08-14  2020.0       4  Seasons
# 5      s6  TV Show    46  Serdar Akar  ... 2017-07-01  2017.0       1   Season
#
# [2 rows x 15 columns]

# %%
df_TVshow.Country.value_counts()    ## Here we use counts function for finding no TV Show.
# Out:
# United States                              705
# United Kingdom                             204
# Japan                                      157
# South Korea                                147
# India                                       71
#                                           ...
# France, Germany                              1
# South Korea, China                           1
# United Kingdom, Singapore                    1
# United Arab Emirates                         1
# United States, Hungary, Ireland, Canada      1
# Name: Country, Length: 183, dtype: int64

# %%
df_TVshow.Country.value_counts().head(1)   ## Here show Highest no of TV Show.
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# # Q16. How we can sort dataset by Year.?

# %%
df.head(2)
# Out:
#   Show_Id Category  Title  ...    Year Minutes     Unit
# 0      s1  TV Show     3%  ...  2020.0       4  Seasons
# 1      s2    Movie  07:19  ...  2016.0      93      min
#
# [2 rows x 15 columns]

# %%
df.sort_values(by='Year').head(2)
# Out:
#      Show_Id Category                 Title  ...    Year Minutes    Unit
# 7115   s7114    Movie  To and From New York  ...  2008.0      81     min
# 1765   s1766  TV Show       Dinner for Five  ...  2008.0       1  Season
#
# [2 rows x 15 columns]

# %%
df.sort_values(by='Year', ascending = False).head(2)
# Out:
#      Show_Id Category            Title  ...    Year Minutes Unit
# 5564   s5564    Movie  Sherlock Holmes  ...  2021.0     128  min
# 5919   s5919    Movie        Surf's Up  ...  2021.0      86  min
#
# [2 rows x 15 columns]

# %% [markdown]
# # Q17. Find all the Instance Where:
#
# Category is 'Movie' and Type is 'Darama'
#
#                  or
#
#
#  Category is 'TV Show' and Type is 'Kids TV'

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas')].head(2)   ## Category is 'Movie' and Type is 'Darama'
# Out:
#   Show_Id Category Title        Director  ...     Date_N    Year Minutes Unit
# 4      s5    Movie    21  Robert Luketic  ... 2020-01-01  2020.0     123  min
# 7      s8    Movie   187  Kevin Reynolds  ... 2019-11-01  2019.0     119  min
#
# [2 rows x 15 columns]

# %%
 df[(df['Category']=='TV Show') & (df['Type']=="Kids' TV")].head(2)
# Out:
#     Show_Id Category         Title  ...    Year Minutes     Unit
# 111    s112  TV Show       44 Cats  ...  2020.0       2  Seasons
# 276    s277  TV Show  Abby Hatcher  ...  2020.0       1   Season
#
# [2 rows x 15 columns]

# %%
df[(df['Category']=='Movie') & (df['Type']=='Dramas') | (df['Category']=='TV Show') & (df['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title  ...    Year Minutes     Unit
# 4         s5    Movie                          21  ...  2020.0     123      min
# 7         s8    Movie                         187  ...  2019.0     119      min
# 111     s112  TV Show                     44 Cats  ...  2020.0       2  Seasons
# 170     s171    Movie                A Family Man  ...  2019.0     110      min
# 232     s233    Movie  A Stoning in Fulham County  ...  2011.0      95      min
# ...      ...      ...                         ...  ...     ...     ...      ...
# 7668   s7667  TV Show               World of Winx  ...  2017.0       2  Seasons
# 7717   s7716  TV Show                        Yoko  ...  2018.0       1   Season
# 7719   s7718  TV Show                         YOM  ...  2018.0       1   Season
# 7758   s7757  TV Show                          Z4  ...  2019.0       2  Seasons
# 7761   s7760  TV Show                   Zak Storm  ...  2018.0       3  Seasons
#
# ...
