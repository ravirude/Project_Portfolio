# %% [markdown]
# <a href="https://colab.research.google.com/github/ravirude/Project_Portfolio/blob/main/COVID_19_REAL_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("covid_19_clean_complete.csv")

# %%
df.count()  ## Null value means Missing Values
# Out:
# Province/State    14664
# Country/Region    49068
# Lat               49068
# Long              49068
# Date              49068
# Confirmed         49068
# Deaths            49068
# Recovered         49068
# Active            49068
# WHO Region        49068
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# # Q1.Show the number of Confirmed,Recovery and Death case in each Reigion.

# %%
df.head(2)
# Out:
#   Province/State Country/Region  ...  Active             WHO Region
# 0            NaN    Afghanistan  ...       0  Eastern Mediterranean
# 1            NaN        Albania  ...       0                 Europe
#
# [2 rows x 10 columns]

# %%
df.groupby('Country/Region').sum().head(5)
# Out:
#                        Lat          Long  Confirmed  Deaths  Recovered   Active
# Country/Region
# Afghanistan     6380.55268  12729.471164    1936390   49098     798240  1089052
# Albania         7736.82040   3791.640400     196702    5708     118877    72117
# Algeria         5270.37320    312.004800    1179755   77972     755897   345886
# Andorra         7991.18440    286.098400      94404    5423      69074    19907
# Angola         -2106.10760   3360.293200      22662    1078       6573    15011

# %%
df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending = False).head(20)
# Out:
# Country/Region
# US                224345948
# Brazil             89524967
# Russia             45408411
# India              40883464
# Spain              27404045
# United Kingdom     26748587
# Italy              26745145
# France             21210926
# Germany            21059152
# Iran               19339267
# Peru               19263916
# Turkey             17903345
# Chile              16935654
# Mexico             14946202
# China              14132002
# Pakistan           12833994
# Saudi Arabia       12362961
# South Africa       11168743
# Canada              9356551
# Bangladesh          8754729
# Name: Confirmed, dtype: int64

# %%
df.groupby('Country/Region')['Confirmed', 'Recovered'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Confirmed  Recovered
# Country/Region
# Afghanistan           1936390     798240
# Albania                196702     118877
# Algeria               1179755     755897
# Andorra                 94404      69074
# Angola                  22662       6573
# ...                       ...        ...
# West Bank and Gaza     233461      61124
# Western Sahara            901        648
# Yemen                   67180      23779
# Zambia                 129421      83611
# Zimbabwe                50794      12207
#
# [187 rows x 2 columns]

# %%
df.head(2)
# Out:
#   Province/State Country/Region  ...  Active             WHO Region
# 0            NaN    Afghanistan  ...       0  Eastern Mediterranean
# 1            NaN        Albania  ...       0                 Europe
#
# [2 rows x 10 columns]

# %% [markdown]
# # Q2. Remove all records where Confirmed cases is Less Than 10.

# %%
df[df.Confirmed < 10]
# Out:
#                   Province/State  Country/Region  ...  Active             WHO Region
# 0                            NaN     Afghanistan  ...       0  Eastern Mediterranean
# 1                            NaN         Albania  ...       0                 Europe
# 2                            NaN         Algeria  ...       0                 Africa
# 3                            NaN         Andorra  ...       0                 Europe
# 4                            NaN          Angola  ...       0                 Africa
# ...                          ...             ...  ...     ...                    ...
# 48918           Saint Barthelemy          France  ...       1                 Europe
# 49048      Northwest Territories          Canada  ...       5               Americas
# 49052                   Anguilla  United Kingdom  ...       0                 Europe
# 49053     British Virgin Islands  United Kingdom  ...       0                 Europe
# ...

# %%
df[~(df.Confirmed < 10)]   ### IF We want to Remove < 10 values then we use ~ this sing
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 49           Beijing                  China  ...      14        Western Pacific
# 53         Guangdong                  China  ...      26        Western Pacific
# 61             Hubei                  China  ...     399        Western Pacific
# 80          Zhejiang                  China  ...      10        Western Pacific
# 310          Beijing                  China  ...      22        Western Pacific
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# ...

# %%
df
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 0                NaN            Afghanistan  ...       0  Eastern Mediterranean
# 1                NaN                Albania  ...       0                 Europe
# 2                NaN                Algeria  ...       0                 Africa
# 3                NaN                Andorra  ...       0                 Europe
# 4                NaN                 Angola  ...       0                 Africa
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# ...

# %%
df = df[~(df.Confirmed < 10)]  ## To Remove records satisfying a particular condition permanetly.

# %%
df
# Out:
#       Province/State         Country/Region  ...  Active             WHO Region
# 49           Beijing                  China  ...      14        Western Pacific
# 53         Guangdong                  China  ...      26        Western Pacific
# 61             Hubei                  China  ...     399        Western Pacific
# 80          Zhejiang                  China  ...      10        Western Pacific
# 310          Beijing                  China  ...      22        Western Pacific
# ...              ...                    ...  ...     ...                    ...
# 49063            NaN  Sao Tome and Principe  ...     117                 Africa
# 49064            NaN                  Yemen  ...     375  Eastern Mediterranean
# 49065            NaN                Comoros  ...      19                 Africa
# 49066            NaN             Tajikistan  ...    1147                 Europe
# 49067            NaN                Lesotho  ...     365                 Africa
#
# ...

# %% [markdown]
# # Q3. In which Region Maximum number of Confirmed cases recorded.

# %%
df.groupby('Country/Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Country/Region
# US                224345894
# Brazil             89524948
# Russia             45408336
# India              40883365
# Spain              27403999
# United Kingdom     26746937
# Italy              26745089
# France             21209656
# Germany            21059126
# Iran               19339260
# Peru               19263901
# Turkey             17903327
# Chile              16935622
# Mexico             14946131
# China              14131308
# Pakistan           12833937
# Saudi Arabia       12362943
# South Africa       11168727
# Canada              9355329
# Bangladesh          8754695
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q4. In which Region Minimum number of Death cases recorded.

# %%
df.groupby('Country/Region').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Country/Region
# Fiji                                 0
# Cambodia                             0
# Dominica                             0
# Eritrea                              0
# Seychelles                           0
# Greenland                            0
# Grenada                              0
# Timor-Leste                          0
# Holy See                             0
# Vietnam                              0
# Saint Lucia                          0
# Saint Kitts and Nevis                0
# Laos                                 0
# Mongolia                             0
# Saint Vincent and the Grenadines     0
# Bhutan                               0
# Papua New Guinea                     2
# Uganda                               6
# Western Sahara                      36
# Namibia                             72
# Name: Deaths, dtype: int64

# %% [markdown]
# # Q5. How Many Confirmed,Recovery, Deaths, case where reported from India till 29 April 2020

# %%
df[df.Country/Region == 'US']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-145-d2023820438d> in <module>()
# ----> 1 df[df.Country/Region == 'US']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Country'

# %% [markdown]
# # Q6. Short the entiredata wrt no confirmed cases in ascending order

# %%
df.sort_values(by = ['Confirmed'], ascending = True)
# Out:
#       Province/State  Country/Region  ...   Active       WHO Region
# 12933            NaN          Latvia  ...        9           Europe
# 9986           Macau           China  ...        2  Western Pacific
# 43842            NaN  Western Sahara  ...        1           Africa
# 26302            NaN        Suriname  ...        1         Americas
# 22126            NaN        Suriname  ...        3         Americas
# ...              ...             ...  ...      ...              ...
# 47986            NaN              US  ...  2661117         Americas
# 48247            NaN              US  ...  2705347         Americas
# 48508            NaN              US  ...  2753091         Americas
# 48769            NaN              US  ...  2789125         Americas
# 49030            NaN              US  ...  2816444         Americas
#
# [35019 rows x 10 columns]

# %% [markdown]
# # Q7.Short the entiredata wrt no Recovered cases in desending order

# %%
df.sort_values(by = ['Recovered'], ascending = False)
# Out:
#          Province/State Country/Region  ...  Active       WHO Region
# 48835               NaN         Brazil  ...  508116         Americas
# 48574               NaN         Brazil  ...  519174         Americas
# 48313               NaN         Brazil  ...  522705         Americas
# 48052               NaN         Brazil  ...  564914         Americas
# 47791               NaN         Brazil  ...  583080         Americas
# ...                 ...            ...  ...     ...              ...
# 42580          Manitoba         Canada  ...     318         Americas
# 42579  British Columbia         Canada  ...    2770         Americas
# 42578           Alberta         Canada  ...    8104         Americas
# 18698               NaN    Netherlands  ...   13358           Europe
# 49              Beijing          China  ...      14  Western Pacific
#
# [35019 rows x 10 columns]
